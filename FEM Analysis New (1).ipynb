# %%
import pandas as pd
import warnings

# Suppress potential warnings from pandas
warnings.filterwarnings('ignore')

# --- 1. Define File Path and Master Columns ---

# The file path for your combined dataset.
file_path = r"Female complete Data CSV.csv" # The updated file path

# A master list of all relevant columns for the analysis.
master_columns = [
    'Gender', # We need this to filter for female data
    'Transgender', 'Sexual Orientation', 'Hispanic Ethnicity', 'Race',
    'Living Situation', 'Household Composition', 'Preferred Language',
    'Religious Preference', 'Veteran Status', 'Employment Status',
    'Number Of Hours Worked Each Week', 'Education Status',
    'Special Education Services',
    'Intellectual Disability', 'Autism Spectrum',
    'Other Developmental Disability', 'Alcohol Related Disorder',
    'Drug Substance Disorder', 'Opioid Related Disorder',
    'Mobility Impairment Disorder', 'Hearing Impairment',
    'Visual Impairment', 'Speech Impairment', 'Hyperlipidemia',
    'High Blood Pressure', 'Diabetes', 'Obesity', 'Heart Attack',
    'Stroke', 'Other Cardiac', 'Pulmonary Asthma',
    'Alzheimer or Dementia', 'Kidney Disease', 'Liver Disease',
    'Endocrine Condition', 'Neurological Condition',
    'Traumatic Brain Injury', 'Joint Disease', 'Cancer',
    'Other Chronic Med Condition', 'No Chronic Med Condition',
    'Unknown Chronic Med Condition', 'Cannabis Recreational Use',
    'Cannabis Medicinal Use', 'Smokes', 'Received Smoking Counseling',
    'Serious Mental Illness', 'Alcohol 12m Service',
    'Opioid 12m Service', 'Drug/Substance 12m Service',
    'Principal Diagnosis Class', 'Criminal Justice Status',
    'Region Served',
    'Mental Illness'
]

# --- 2. Load Data and Filter for Female Records ---

try:
    data = pd.read_csv(file_path)
    print("Data loaded successfully!")
except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}")
    exit()

# Filter data to include only the female records
female_data = data[data['Gender'] == 'FEMALE'].copy()
female_data.drop(columns=['Gender'], inplace=True)
female_data = female_data[master_columns] # Filter to master list

print(f"Female data shape: {female_data.shape}")
print("\nFemale data filtered successfully!")

# --- 3. Exploratory Data Analysis (EDA) ---

print("\n--- EDA: Analysis of Missing Values (UNKNOWN) ---")
# Count the number of 'UNKNOWN' values for each column
for col in female_data.columns:
    unknown_count = (female_data[col] == 'UNKNOWN').sum()
    if unknown_count > 0:
        print(f"Column '{col}': {unknown_count} UNKNOWN values")

print("\n--- EDA: Geographic Disparities in UNKNOWN values ---")
# Analyze UNKNOWN values by region
regions = female_data['Region Served'].unique()
for col in female_data.columns:
    unknown_by_region = female_data[female_data[col] == 'UNKNOWN'].groupby('Region Served')[col].count()
    if not unknown_by_region.empty:
        print(f"\nUNKNOWN values in column '{col}' by Region:")
        print(unknown_by_region)

print("\n--- EDA: Class Distribution of the Target Variable ---")
# Check the distribution of the target variable 'Mental Illness'
target_distribution = female_data['Mental Illness'].value_counts()
print(target_distribution)

print("\n--- EDA Complete ---")
print("The EDA has been performed, and the results are ready for interpretation.")
# Out:
# Data loaded successfully!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 50
#      47     exit()
#      49 # Filter data to include only the female records
# ---> 50 female_data = data[data['Gender'] == 'FEMALE'].copy()
#      51 female_data.drop(columns=['Gender'], inplace=True)
#      52 female_data = female_data[master_columns] # Filter to master list
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Gender'

# %%
import pandas as pd
import warnings

# Suppress potential warnings from pandas
warnings.filterwarnings('ignore')

# --- 1. Define File Path and Master Columns ---

# The file path for your female-only dataset.
file_path = r"Female complete Data CSV.csv"

# A master list of all relevant columns for the analysis.
# The 'Gender' column has been removed since the data is already filtered.
master_columns = [
    'Transgender', 'Sexual Orientation', 'Hispanic Ethnicity', 'Race',
    'Living Situation', 'Household Composition', 'Preferred Language',
    'Religious Preference', 'Veteran Status', 'Employment Status',
    'Number Of Hours Worked Each Week', 'Education Status',
    'Special Education Services',
    'Intellectual Disability', 'Autism Spectrum',
    'Other Developmental Disability', 'Alcohol Related Disorder',
    'Drug Substance Disorder', 'Opioid Related Disorder',
    'Mobility Impairment Disorder', 'Hearing Impairment',
    'Visual Impairment', 'Speech Impairment', 'Hyperlipidemia',
    'High Blood Pressure', 'Diabetes', 'Obesity', 'Heart Attack',
    'Stroke', 'Other Cardiac', 'Pulmonary Asthma',
    'Alzheimer or Dementia', 'Kidney Disease', 'Liver Disease',
    'Endocrine Condition', 'Neurological Condition',
    'Traumatic Brain Injury', 'Joint Disease', 'Cancer',
    'Other Chronic Med Condition', 'No Chronic Med Condition',
    'Unknown Chronic Med Condition', 'Cannabis Recreational Use',
    'Cannabis Medicinal Use', 'Smokes', 'Received Smoking Counseling',
    'Serious Mental Illness', 'Alcohol 12m Service',
    'Opioid 12m Service', 'Drug/Substance 12m Service',
    'Principal Diagnosis Class', 'Criminal Justice Status',
    'Region Served',
    'Mental Illness'
]

# --- 2. Load Data ---

try:
    data = pd.read_csv(file_path)
    print("Data loaded successfully!")
except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}")
    exit()

# The data is already filtered for females, so we just select the master columns
female_data = data[master_columns].copy()

print(f"Female data shape: {female_data.shape}")
print("\nFemale data is ready for analysis!")

# --- 3. Exploratory Data Analysis (EDA) ---

print("\n--- EDA: Analysis of Missing Values (UNKNOWN) ---")
# Count the number of 'UNKNOWN' values for each column
for col in female_data.columns:
    unknown_count = (female_data[col] == 'UNKNOWN').sum()
    if unknown_count > 0:
        print(f"Column '{col}': {unknown_count} UNKNOWN values")

print("\n--- EDA: Geographic Disparities in UNKNOWN values ---")
# Analyze UNKNOWN values by region
regions = female_data['Region Served'].unique()
for col in female_data.columns:
    unknown_by_region = female_data[female_data[col] == 'UNKNOWN'].groupby('Region Served')[col].count()
    if not unknown_by_region.empty:
        print(f"\nUNKNOWN values in column '{col}' by Region:")
        print(unknown_by_region)

print("\n--- EDA: Class Distribution of the Target Variable ---")
# Check the distribution of the target variable 'Mental Illness'
target_distribution = female_data['Mental Illness'].value_counts()
print(target_distribution)

print("\n--- EDA Complete ---")
print("The EDA has been performed, and the results are ready for interpretation.")
# Out:
# Data loaded successfully!
# Female data shape: (99244, 54)
#
# Female data is ready for analysis!
#
# --- EDA: Analysis of Missing Values (UNKNOWN) ---
# Column 'Transgender': 6740 UNKNOWN values
# Column 'Sexual Orientation': 12598 UNKNOWN values
# Column 'Hispanic Ethnicity': 2902 UNKNOWN values
# Column 'Living Situation': 4493 UNKNOWN values
# Column 'Household Composition': 5226 UNKNOWN values
# Column 'Preferred Language': 1460 UNKNOWN values
# Column 'Veteran Status': 3882 UNKNOWN values
# Column 'Education Status': 10759 UNKNOWN values
# Column 'Special Education Services': 2282 UNKNOWN values
# Column 'Intellectual Disability': 8506 UNKNOWN values
# Column 'Autism Spectrum': 7819 UNKNOWN values
# Column 'Other Developmental Disability': 7889 UNKNOWN values
# Column 'Alcohol Related Disorder': 6033 UNKNOWN values
# Column 'Drug Substance Disorder': 5983 UNKNOWN values
# Column 'Opioid Related Disorder': 7548 UNKNOWN values
# Column 'Mobility Impairment Disorder': 7351 UNKNOWN values
# Column 'Hearing Impairment': 7726 UNKNOWN values
# Column 'Visual Impairment': 7717 UNKNOWN values
# Column 'Speech Impairment': 7751 UNKNOWN values
# Column 'Hyperlipidemia': 6829 UNKNOWN values
# Column 'High Blood Pressure': 6829 UNKNOWN values
# Column 'Diabetes': 6829 UNKNOWN values
# Column 'Obesity': 6829 UNKNOWN values
# Column 'Heart Attack': 6829 UNKNOWN values
# Column 'Stroke': 6829 UNKNOWN values
# Column 'Other Cardiac': 6829 UNKNOWN values
# Column 'Pulmonary Asthma': 6829 UNKNOWN values
# Column 'Alzheimer or Dementia': 6829 UNKNOWN values
# Column 'Kidney Disease': 6829 UNKNOWN values
# Column 'Liver Disease': 6829 UNKNOWN values
# Column 'Endocrine Condition': 6829 UNKNOWN values
# Column 'Neurological Condition': 6829 UNKNOWN values
# Column 'Traumatic Brain Injury': 6829 UNKNOWN values
# Column 'Joint Disease': 6829 UNKNOWN values
# Column 'Cancer': 6829 UNKNOWN values
# Column 'Other Chronic Med Condition': 6829 UNKNOWN values
# Column 'No Chronic Med Condition': 6829 UNKNOWN values
# Column 'Cannabis Recreational Use': 10137 UNKNOWN values
# Column 'Cannabis Medicinal Use': 11858 UNKNOWN values
# Column 'Smokes': 8016 UNKNOWN values
# Column 'Received Smoking Counseling': 8473 UNKNOWN values
# Column 'Serious Mental Illness': 570 UNKNOWN values
# Column 'Alcohol 12m Service': 8040 UNKNOWN values
# Column 'Opioid 12m Service': 7951 UNKNOWN values
# Column 'Drug/Substance 12m Service': 8242 UNKNOWN values
# Column 'Principal Diagnosis Class': 3525 UNKNOWN values
# Column 'Criminal Justice Status': 8628 UNKNOWN values
# Column 'Mental Illness': 988 UNKNOWN values
#
# --- EDA: Geographic Disparities in UNKNOWN values ---
#
# UNKNOWN values in column 'Transgender' by Region:
# Region Served
# CENTRAL NY REGION        558
# HUDSON RIVER REGION      373
# LONG ISLAND REGION       286
# NEW YORK CITY REGION    3630
# WESTERN REGION          1893
# Name: Transgender, dtype: int64
#
# UNKNOWN values in column 'Sexual Orientation' by Region:
# Region Served
# CENTRAL NY REGION       1179
# HUDSON RIVER REGION     1494
# LONG ISLAND REGION       721
# NEW YORK CITY REGION    5985
# WESTERN REGION          3219
# Name: Sexual Orientation, dtype: int64
#
# UNKNOWN values in column 'Hispanic Ethnicity' by Region:
# Region Served
# CENTRAL NY REGION        307
# HUDSON RIVER REGION      565
# LONG ISLAND REGION       139
# NEW YORK CITY REGION    1296
# WESTERN REGION           595
# Name: Hispanic Ethnicity, dtype: int64
#
# UNKNOWN values in column 'Living Situation' by Region:
# Region Served
# CENTRAL NY REGION        262
# HUDSON RIVER REGION      420
# LONG ISLAND REGION       364
# NEW YORK CITY REGION    3088
# WESTERN REGION           359
# Name: Living Situation, dtype: int64
#
# UNKNOWN values in column 'Household Composition' by Region:
# Region Served
# CENTRAL NY REGION        234
# HUDSON RIVER REGION      514
# LONG ISLAND REGION       404
# NEW YORK CITY REGION    3696
# WESTERN REGION           378
# Name: Household Composition, dtype: int64
#
# UNKNOWN values in column 'Preferred Language' by Region:
# Region Served
# CENTRAL NY REGION       197
# HUDSON RIVER REGION     165
# LONG ISLAND REGION       25
# NEW YORK CITY REGION    894
# WESTERN REGION          179
# Name: Preferred Language, dtype: int64
#
# UNKNOWN values in column 'Veteran Status' by Region:
# Region Served
# CENTRAL NY REGION        192
# HUDSON RIVER REGION      388
# LONG ISLAND REGION       297
# NEW YORK CITY REGION    2088
# WESTERN REGION           917
# Name: Veteran Status, dtype: int64
#
# UNKNOWN values in column 'Education Status' by Region:
# Region Served
# CENTRAL NY REGION        881
# HUDSON RIVER REGION     1270
# LONG ISLAND REGION       661
# NEW YORK CITY REGION    6200
# WESTERN REGION          1747
# Name: Education Status, dtype: int64
#
# UNKNOWN values in column 'Special Education Services' by Region:
# Region Served
# CENTRAL NY REGION        307
# HUDSON RIVER REGION      463
# LONG ISLAND REGION       163
# NEW YORK CITY REGION    1009
# WESTERN REGION           340
# Name: Special Education Services, dtype: int64
#
# UNKNOWN values in column 'Intellectual Disability' by Region:
# Region Served
# CENTRAL NY REGION        804
# HUDSON RIVER REGION     1309
# LONG ISLAND REGION       299
# NEW YORK CITY REGION    5021
# WESTERN REGION          1073
# Name: Intellectual Disability, dtype: int64
#
# UNKNOWN values in column 'Autism Spectrum' by Region:
# Region Served
# CENTRAL NY REGION        700
# HUDSON RIVER REGION     1157
# LONG ISLAND REGION       266
# NEW YORK CITY REGION    4739
# WESTERN REGION           957
# Name: Autism Spectrum, dtype: int64
#
# UNKNOWN values in column 'Other Developmental Disability' by Region:
# Region Served
# CENTRAL NY REGION        719
# HUDSON RIVER REGION     1185
# LONG ISLAND REGION       269
# NEW YORK CITY REGION    4725
# WESTERN REGION           991
# Name: Other Developmental Disability, dtype: int64
#
# UNKNOWN values in column 'Alcohol Related Disorder' by Region:
# Region Served
# CENTRAL NY REGION        596
# HUDSON RIVER REGION      976
# LONG ISLAND REGION       206
# NEW YORK CITY REGION    3527
# WESTERN REGION           728
# Name: Alcohol Related Disorder, dtype: int64
#
# UNKNOWN values in column 'Drug Substance Disorder' by Region:
# Region Served
# CENTRAL NY REGION        600
# HUDSON RIVER REGION      968
# LONG ISLAND REGION       197
# NEW YORK CITY REGION    3507
# WESTERN REGION           711
# Name: Drug Substance Disorder, dtype: int64
#
# UNKNOWN values in column 'Opioid Related Disorder' by Region:
# Region Served
# CENTRAL NY REGION        799
# HUDSON RIVER REGION     1106
# LONG ISLAND REGION       249
# NEW YORK CITY REGION    4578
# WESTERN REGION           816
# Name: Opioid Related Disorder, dtype: int64
#
# UNKNOWN values in column 'Mobility Impairment Disorder' by Region:
# Region Served
# CENTRAL NY REGION        771
# HUDSON RIVER REGION     1045
# LONG ISLAND REGION       398
# NEW YORK CITY REGION    4432
# WESTERN REGION           705
# Name: Mobility Impairment Disorder, dtype: int64
#
# UNKNOWN values in column 'Hearing Impairment' by Region:
# Region Served
# CENTRAL NY REGION        784
# HUDSON RIVER REGION     1062
# LONG ISLAND REGION       243
# NEW YORK CITY REGION    4915
# WESTERN REGION           722
# Name: Hearing Impairment, dtype: int64
#
# UNKNOWN values in column 'Visual Impairment' by Region:
# Region Served
# CENTRAL NY REGION        772
# HUDSON RIVER REGION     1056
# LONG ISLAND REGION       241
# NEW YORK CITY REGION    4912
# WESTERN REGION           736
# Name: Visual Impairment, dtype: int64
#
# UNKNOWN values in column 'Speech Impairment' by Region:
# Region Served
# CENTRAL NY REGION        786
# HUDSON RIVER REGION     1071
# LONG ISLAND REGION       248
# NEW YORK CITY REGION    4925
# WESTERN REGION           721
# Name: Speech Impairment, dtype: int64
#
# UNKNOWN values in column 'Hyperlipidemia' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Hyperlipidemia, dtype: int64
#
# UNKNOWN values in column 'High Blood Pressure' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: High Blood Pressure, dtype: int64
#
# UNKNOWN values in column 'Diabetes' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Diabetes, dtype: int64
#
# UNKNOWN values in column 'Obesity' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Obesity, dtype: int64
#
# UNKNOWN values in column 'Heart Attack' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Heart Attack, dtype: int64
#
# UNKNOWN values in column 'Stroke' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Stroke, dtype: int64
#
# UNKNOWN values in column 'Other Cardiac' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Other Cardiac, dtype: int64
#
# UNKNOWN values in column 'Pulmonary Asthma' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Pulmonary Asthma, dtype: int64
#
# UNKNOWN values in column 'Alzheimer or Dementia' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Alzheimer or Dementia, dtype: int64
#
# UNKNOWN values in column 'Kidney Disease' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Kidney Disease, dtype: int64
#
# UNKNOWN values in column 'Liver Disease' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Liver Disease, dtype: int64
#
# UNKNOWN values in column 'Endocrine Condition' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Endocrine Condition, dtype: int64
#
# UNKNOWN values in column 'Neurological Condition' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Neurological Condition, dtype: int64
#
# UNKNOWN values in column 'Traumatic Brain Injury' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Traumatic Brain Injury, dtype: int64
#
# UNKNOWN values in column 'Joint Disease' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Joint Disease, dtype: int64
#
# UNKNOWN values in column 'Cancer' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Cancer, dtype: int64
#
# UNKNOWN values in column 'Other Chronic Med Condition' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: Other Chronic Med Condition, dtype: int64
#
# UNKNOWN values in column 'No Chronic Med Condition' by Region:
# Region Served
# CENTRAL NY REGION        482
# HUDSON RIVER REGION      878
# LONG ISLAND REGION       215
# NEW YORK CITY REGION    4286
# WESTERN REGION           968
# Name: No Chronic Med Condition, dtype: int64
#
# UNKNOWN values in column 'Cannabis Recreational Use' by Region:
# Region Served
# CENTRAL NY REGION       1098
# HUDSON RIVER REGION     1349
# LONG ISLAND REGION       509
# NEW YORK CITY REGION    5529
# WESTERN REGION          1652
# Name: Cannabis Recreational Use, dtype: int64
#
# UNKNOWN values in column 'Cannabis Medicinal Use' by Region:
# Region Served
# CENTRAL NY REGION        996
# HUDSON RIVER REGION     1190
# LONG ISLAND REGION       511
# NEW YORK CITY REGION    7704
# WESTERN REGION          1457
# Name: Cannabis Medicinal Use, dtype: int64
#
# UNKNOWN values in column 'Smokes' by Region:
# Region Served
# CENTRAL NY REGION        809
# HUDSON RIVER REGION     1170
# LONG ISLAND REGION       387
# NEW YORK CITY REGION    4384
# WESTERN REGION          1266
# Name: Smokes, dtype: int64
#
# UNKNOWN values in column 'Received Smoking Counseling' by Region:
# Region Served
# CENTRAL NY REGION        808
# HUDSON RIVER REGION      873
# LONG ISLAND REGION       482
# NEW YORK CITY REGION    5231
# WESTERN REGION          1079
# Name: Received Smoking Counseling, dtype: int64
#
# UNKNOWN values in column 'Serious Mental Illness' by Region:
# Region Served
# CENTRAL NY REGION        76
# HUDSON RIVER REGION     128
# LONG ISLAND REGION       21
# NEW YORK CITY REGION    174
# WESTERN REGION          171
# Name: Serious Mental Illness, dtype: int64
#
# UNKNOWN values in column 'Alcohol 12m Service' by Region:
# Region Served
# CENTRAL NY REGION        678
# HUDSON RIVER REGION      768
# LONG ISLAND REGION       453
# NEW YORK CITY REGION    5258
# WESTERN REGION           883
# Name: Alcohol 12m Service, dtype: int64
#
# UNKNOWN values in column 'Opioid 12m Service' by Region:
# Region Served
# CENTRAL NY REGION        683
# HUDSON RIVER REGION      774
# LONG ISLAND REGION       459
# NEW YORK CITY REGION    5150
# WESTERN REGION           885
# Name: Opioid 12m Service, dtype: int64
#
# UNKNOWN values in column 'Drug/Substance 12m Service' by Region:
# Region Served
# CENTRAL NY REGION        685
# HUDSON RIVER REGION      927
# LONG ISLAND REGION       458
# NEW YORK CITY REGION    5281
# WESTERN REGION           891
# Name: Drug/Substance 12m Service, dtype: int64
#
# UNKNOWN values in column 'Principal Diagnosis Class' by Region:
# Region Served
# CENTRAL NY REGION        222
# HUDSON RIVER REGION      533
# LONG ISLAND REGION       568
# NEW YORK CITY REGION    1615
# WESTERN REGION           587
# Name: Principal Diagnosis Class, dtype: int64
#
# UNKNOWN values in column 'Criminal Justice Status' by Region:
# Region Served
# CENTRAL NY REGION        727
# HUDSON RIVER REGION      946
# LONG ISLAND REGION       536
# NEW YORK CITY REGION    5342
# WESTERN REGION          1077
# Name: Criminal Justice Status, dtype: int64
#
# UNKNOWN values in column 'Mental Illness' by Region:
# Region Served
# CENTRAL NY REGION       110
# HUDSON RIVER REGION     147
# LONG ISLAND REGION       37
# NEW YORK CITY REGION    523
# WESTERN REGION          171
# Name: Mental Illness, dtype: int64
#
# --- EDA: Class Distribution of the Target Variable ---
# Mental Illness
# YES        95693
# NO          2563
# UNKNOWN      988
# Name: count, dtype: int64
#
# --- EDA Complete ---
# The EDA has been performed, and the results are ready for interpretation.
